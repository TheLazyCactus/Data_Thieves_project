# %% [markdown]
# Call CSV file

# %%
import pandas as pd
import numpy as np
url1 = 'https://raw.githubusercontent.com/TheLazyCactus/Data_Thieves_project/refs/heads/main/Cat%20Scraped.csv'
url2 = 'https://raw.githubusercontent.com/TheLazyCactus/Data_Thieves_project/refs/heads/main/Dog%20Scraped.csv'
url3 = 'https://raw.githubusercontent.com/TheLazyCactus/Data_Thieves_project/refs/heads/main/retirement_homes_df.csv'
url4 = 'https://raw.githubusercontent.com/TheLazyCactus/Data_Thieves_project/refs/heads/main/schools_df.csv'
cat_data = pd.read_csv(url1, sep=";", low_memory =False)
dog_data = pd.read_csv(url2, sep=";", low_memory =False, encoding="latin1")
retirement_data = pd.read_csv(url3, sep=",", low_memory =False)
schools_df = pd.read_csv(url4, sep=",", low_memory =False)

# %% [markdown]
# Dict creation of place/location

# %%
dog_data
# Out:
#    ï»¿Column1.1         Column1.2    Column1.3 Column1.4    Column1.5  \
# 0          NAME    Street Address         City     State  Postal Code
# 1         Lizzy               NaN  Los Angeles        CA        90210
# 2        Autumn               NaN  Los Angeles        CA        90210
# 3        Cookie               NaN  Los Angeles        CA        90210
# 4        Buster   999 Main street  Los Angeles        CA        90067
# ..          ...               ...          ...       ...          ...
# 91       Watson  3201 Lacy Street  Los Angeles        CA        90031
# 92         Zara  3201 Lacy Street  Los Angeles        CA        90031
# 93        Ellie  3201 Lacy Street  Los Angeles        CA        90031
# 94    Valentina  3201 Lacy Street  Los Angeles        CA        90031
# 95     Cafesita  3201 Lacy Street  Los Angeles        CA        90031
#
#    Column1.6                   Column1.7                         Column1.8  \
# 0        Age                       Breed                             Email
# 1      Puppy                 Terrier Mix             lindaelee@hotmail.com
# 2      Puppy                 Terrier Mix             lindaelee@hotmail.com
# 3      Young            Pit Bull Terrier  info@thecatsmeowanimalrescue.org
# 4      Adult            Pit Bull Terrier           idonotownacat@gmail.com
# ..       ...                         ...                               ...
# 91     Adult  Staffordshire Bull Terrier            DawnVargas05@yahoo.com
# 92     Adult                 Mixed Breed            DawnVargas05@yahoo.com
# 93     Young         German Shepherd Dog            DawnVargas05@yahoo.com
# 94     Young              Siberian Husky      Herehaveakitteninc@gmail.com
# 95     Adult            Pit Bull Terrier      Herehaveakitteninc@gmail.com
#
#          Column1.9                                         Column1.10  ...  \
# 0        Telephone                                          Image URL  ...
# 1     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/09...  ...
# 2     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/db...  ...
# 3     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/47...  ...
# 4     206-524-3066  https://dbw3zep4prcju.cloudfront.net/animal/60...  ...
# ..             ...                                                ...  ...
# 91  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/cd...  ...
# 92  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a5...  ...
# 93  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a9...  ...
# 94  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/5b...  ...
# 95  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/76...  ...
#
#    Column2  Column3  Column4  Column5  Column6  Column7  Column8  Column9  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ..     ...      ...      ...      ...      ...      ...      ...      ...
# 91     NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 92     NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 93     NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 94     NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 95     NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#     Column10  Column11
# 0        NaN       NaN
# 1        NaN       NaN
# 2        NaN       NaN
# 3        NaN       NaN
# 4        NaN       NaN
# ..       ...       ...
# 91       NaN       NaN
# 92       NaN       NaN
# 93       NaN       NaN
# 94       NaN       NaN
# 95       NaN       NaN
#
# [96 rows x 21 columns]

# %%
dog_data.columns = dog_data.iloc[0]
dog_data = dog_data[1:].reset_index(drop=True)

# %%
dog_data
# Out:
# 0        NAME    Street Address         City State Postal Code    Age  \
# 0       Lizzy               NaN  Los Angeles    CA       90210  Puppy
# 1      Autumn               NaN  Los Angeles    CA       90210  Puppy
# 2      Cookie               NaN  Los Angeles    CA       90210  Young
# 3      Buster   999 Main street  Los Angeles    CA       90067  Adult
# 4        Abby   999 Main street  Los Angeles    CA       90067  Adult
# ..        ...               ...          ...   ...         ...    ...
# 90     Watson  3201 Lacy Street  Los Angeles    CA       90031  Adult
# 91       Zara  3201 Lacy Street  Los Angeles    CA       90031  Adult
# 92      Ellie  3201 Lacy Street  Los Angeles    CA       90031  Young
# 93  Valentina  3201 Lacy Street  Los Angeles    CA       90031  Young
# 94   Cafesita  3201 Lacy Street  Los Angeles    CA       90031  Adult
#
# 0                            Breed                             Email  \
# 0                      Terrier Mix             lindaelee@hotmail.com
# 1                      Terrier Mix             lindaelee@hotmail.com
# 2                 Pit Bull Terrier  info@thecatsmeowanimalrescue.org
# 3                 Pit Bull Terrier           idonotownacat@gmail.com
# 4   American Staffordshire Terrier           idonotownacat@gmail.com
# ..                             ...                               ...
# 90      Staffordshire Bull Terrier            DawnVargas05@yahoo.com
# 91                     Mixed Breed            DawnVargas05@yahoo.com
# 92             German Shepherd Dog            DawnVargas05@yahoo.com
# 93                  Siberian Husky      Herehaveakitteninc@gmail.com
# 94                Pit Bull Terrier      Herehaveakitteninc@gmail.com
#
# 0        Telephone                                          Image URL  ...  \
# 0     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/09...  ...
# 1     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/db...  ...
# 2     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/47...  ...
# 3     206-524-3066  https://dbw3zep4prcju.cloudfront.net/animal/60...  ...
# 4     916-296-5195  https://dbw3zep4prcju.cloudfront.net/animal/d7...  ...
# ..             ...                                                ...  ...
# 90  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/cd...  ...
# 91  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a5...  ...
# 92  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a9...  ...
# 93  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/5b...  ...
# 94  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/76...  ...
#
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  \
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 90  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 91  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 92  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 93  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 94  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# 0                                   Location
# 0                nan, Los Angeles, CA, 90210
# 1                nan, Los Angeles, CA, 90210
# 2                nan, Los Angeles, CA, 90210
# 3    999 Main street, Los Angeles, CA, 90067
# 4    999 Main street, Los Angeles, CA, 90067
# ..                                       ...
# 90  3201 Lacy Street, Los Angeles, CA, 90031
# 91  3201 Lacy Street, Los Angeles, CA, 90031
# 92  3201 Lacy Street, Los Angeles, CA, 90031
# 93  3201 Lacy Street, Los Angeles, CA, 90031
# 94  3201 Lacy Street, Los Angeles, CA, 90031
#
# [95 rows x 22 columns]

# %%
dog_data["Location"] = dog_data.apply(
    lambda row: f"{row['Street Address']}, {row['City']}, {row['State']}, {row['Postal Code']}",
    axis=1
)

# %%
dog_data = dog_data.dropna(axis=1, how='all')

# %%
dog_data
# Out:
# 0        NAME    Street Address         City State Postal Code    Age  \
# 0       Lizzy               NaN  Los Angeles    CA       90210  Puppy
# 1      Autumn               NaN  Los Angeles    CA       90210  Puppy
# 2      Cookie               NaN  Los Angeles    CA       90210  Young
# 3      Buster   999 Main street  Los Angeles    CA       90067  Adult
# 4        Abby   999 Main street  Los Angeles    CA       90067  Adult
# ..        ...               ...          ...   ...         ...    ...
# 90     Watson  3201 Lacy Street  Los Angeles    CA       90031  Adult
# 91       Zara  3201 Lacy Street  Los Angeles    CA       90031  Adult
# 92      Ellie  3201 Lacy Street  Los Angeles    CA       90031  Young
# 93  Valentina  3201 Lacy Street  Los Angeles    CA       90031  Young
# 94   Cafesita  3201 Lacy Street  Los Angeles    CA       90031  Adult
#
# 0                            Breed                             Email  \
# 0                      Terrier Mix             lindaelee@hotmail.com
# 1                      Terrier Mix             lindaelee@hotmail.com
# 2                 Pit Bull Terrier  info@thecatsmeowanimalrescue.org
# 3                 Pit Bull Terrier           idonotownacat@gmail.com
# 4   American Staffordshire Terrier           idonotownacat@gmail.com
# ..                             ...                               ...
# 90      Staffordshire Bull Terrier            DawnVargas05@yahoo.com
# 91                     Mixed Breed            DawnVargas05@yahoo.com
# 92             German Shepherd Dog            DawnVargas05@yahoo.com
# 93                  Siberian Husky      Herehaveakitteninc@gmail.com
# 94                Pit Bull Terrier      Herehaveakitteninc@gmail.com
#
# 0        Telephone                                          Image URL  \
# 0     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/09...
# 1     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/db...
# 2     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/47...
# 3     206-524-3066  https://dbw3zep4prcju.cloudfront.net/animal/60...
# 4     916-296-5195  https://dbw3zep4prcju.cloudfront.net/animal/d7...
# ..             ...                                                ...
# 90  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/cd...
# 91  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a5...
# 92  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a9...
# 93  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/5b...
# 94  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/76...
#
# 0   Access URL                                  Location
# 0   Click Here               nan, Los Angeles, CA, 90210
# 1   Click Here               nan, Los Angeles, CA, 90210
# 2   Click Here               nan, Los Angeles, CA, 90210
# 3   Click Here   999 Main street, Los Angeles, CA, 90067
# 4   Click Here   999 Main street, Los Angeles, CA, 90067
# ..         ...                                       ...
# 90  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 91  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 92  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 93  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 94  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
#
# [95 rows x 12 columns]

# %% [markdown]
# Transform dict for place/coordinate

# %%
pip install geopy
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    --------- ----------------------------- 30.7/125.4 kB 640.0 kB/s eta 0:00:01
#    ---------------------------------------- 125.4/125.4 kB 1.2 MB/s eta 0:00:00
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#    ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#    ---------------------------------------- 40.3/40.3 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1

# %%
from geopy.geocoders import Nominatim

def address_to_coordinates(address):
    """
    Transforms a given address into geographic coordinates (latitude and longitude).
    
    Args:
        address (str): The address to be geocoded.
        
    Returns:
        tuple: A tuple containing latitude and longitude as floats.
               Returns None if the address cannot be geocoded.
    """
    try:
        # Initialize geolocator
        geolocator = Nominatim(user_agent="address_to_coordinates_app")
        # Geocode the address
        location = geolocator.geocode(address)
        if location:
            return location.latitude, location.longitude
        else:
            print("Address not found.")
            return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None


#Output dict1 and dict2

# %%
dog_data["Coordinate"] = dog_data["Location"].apply(address_to_coordinates)
# Out:
# Address not found.
# Address not found.
# Address not found.
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_36248\782558104.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dog_data["Coordinate"] = dog_data["Location"].apply(address_to_coordinates)

# %%
dog_data["Coordinate"] = dog_data["Coordinate"].fillna("(34.052235, -118.243683)")
# Out:
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_36248\2945465133.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dog_data["Coordinate"] = dog_data["Coordinate"].fillna("(34.052235, -118.243683)")

# %%
dog_data
# Out:
# 0        NAME    Street Address         City State Postal Code    Age  \
# 0       Lizzy               NaN  Los Angeles    CA       90210  Puppy
# 1      Autumn               NaN  Los Angeles    CA       90210  Puppy
# 2      Cookie               NaN  Los Angeles    CA       90210  Young
# 3      Buster   999 Main street  Los Angeles    CA       90067  Adult
# 4        Abby   999 Main street  Los Angeles    CA       90067  Adult
# ..        ...               ...          ...   ...         ...    ...
# 90     Watson  3201 Lacy Street  Los Angeles    CA       90031  Adult
# 91       Zara  3201 Lacy Street  Los Angeles    CA       90031  Adult
# 92      Ellie  3201 Lacy Street  Los Angeles    CA       90031  Young
# 93  Valentina  3201 Lacy Street  Los Angeles    CA       90031  Young
# 94   Cafesita  3201 Lacy Street  Los Angeles    CA       90031  Adult
#
# 0                            Breed                             Email  \
# 0                      Terrier Mix             lindaelee@hotmail.com
# 1                      Terrier Mix             lindaelee@hotmail.com
# 2                 Pit Bull Terrier  info@thecatsmeowanimalrescue.org
# 3                 Pit Bull Terrier           idonotownacat@gmail.com
# 4   American Staffordshire Terrier           idonotownacat@gmail.com
# ..                             ...                               ...
# 90      Staffordshire Bull Terrier            DawnVargas05@yahoo.com
# 91                     Mixed Breed            DawnVargas05@yahoo.com
# 92             German Shepherd Dog            DawnVargas05@yahoo.com
# 93                  Siberian Husky      Herehaveakitteninc@gmail.com
# 94                Pit Bull Terrier      Herehaveakitteninc@gmail.com
#
# 0        Telephone                                          Image URL  \
# 0     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/09...
# 1     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/db...
# 2     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/47...
# 3     206-524-3066  https://dbw3zep4prcju.cloudfront.net/animal/60...
# 4     916-296-5195  https://dbw3zep4prcju.cloudfront.net/animal/d7...
# ..             ...                                                ...
# 90  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/cd...
# 91  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a5...
# 92  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a9...
# 93  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/5b...
# 94  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/76...
#
# 0   Access URL                                  Location  \
# 0   Click Here               nan, Los Angeles, CA, 90210
# 1   Click Here               nan, Los Angeles, CA, 90210
# 2   Click Here               nan, Los Angeles, CA, 90210
# 3   Click Here   999 Main street, Los Angeles, CA, 90067
# 4   Click Here   999 Main street, Los Angeles, CA, 90067
# ..         ...                                       ...
# 90  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 91  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 92  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 93  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 94  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
#
# 0                                 Coordinate
# 0                   (34.052235, -118.243683)
# 1                   (34.052235, -118.243683)
# 2                   (34.052235, -118.243683)
# 3                   (33.991801, -118.473835)
# 4                   (33.991801, -118.473835)
# ..                                       ...
# 90  (34.08370692586621, -118.21807957472903)
# 91  (34.08370692586621, -118.21807957472903)
# 92  (34.08370692586621, -118.21807957472903)
# 93  (34.08370692586621, -118.21807957472903)
# 94  (34.08370692586621, -118.21807957472903)
#
# [95 rows x 13 columns]

# %%
#For address not found replace by 34.052235, -118.243683

# %%
dog_data.to_csv('Dog_CA.csv', index=False)

# %% [markdown]
# Create function to calcuate distance between 2 coordinates

# %%
dog_data["Location"].unique()
# Out:
# array(['nan, Los Angeles, CA, 90210',
#        '999 Main street, Los Angeles, CA, 90067',
#        '3201 Lacy Street, Los Angeles, CA, 90031'], dtype=object)

# %%
import ast

# Convert string representation of tuples to actual tuple
def parse_coordinate(x):
    if isinstance(x, str):
        try:
            # Try converting string representation of tuple to an actual tuple
            return ast.literal_eval(x)
        except:
            return None
    return x  # Return as is if it's already a tuple or list

# Apply the parsing function to the 'Coordinate' column
dog_data['Coordinate'] = dog_data['Coordinate'].apply(parse_coordinate)

dog_coord = dog_data[dog_data['Coordinate'].apply(lambda x: isinstance(x, (list, tuple)) and len(x) == 2)]

# Extract 'lat' and 'lng' from the 'Coordinate' column
dog_coord[['lat', 'lng']] = pd.DataFrame(dog_coord['Coordinate'].tolist(), index=dog_coord.index)
# Out:
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_36248\3256334826.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dog_data['Coordinate'] = dog_data['Coordinate'].apply(parse_coordinate)

# %%
dog_coord
# Out:
# 0        NAME    Street Address         City State Postal Code    Age  \
# 0       Lizzy               NaN  Los Angeles    CA       90210  Puppy
# 1      Autumn               NaN  Los Angeles    CA       90210  Puppy
# 2      Cookie               NaN  Los Angeles    CA       90210  Young
# 3      Buster   999 Main street  Los Angeles    CA       90067  Adult
# 4        Abby   999 Main street  Los Angeles    CA       90067  Adult
# ..        ...               ...          ...   ...         ...    ...
# 90     Watson  3201 Lacy Street  Los Angeles    CA       90031  Adult
# 91       Zara  3201 Lacy Street  Los Angeles    CA       90031  Adult
# 92      Ellie  3201 Lacy Street  Los Angeles    CA       90031  Young
# 93  Valentina  3201 Lacy Street  Los Angeles    CA       90031  Young
# 94   Cafesita  3201 Lacy Street  Los Angeles    CA       90031  Adult
#
# 0                            Breed                             Email  \
# 0                      Terrier Mix             lindaelee@hotmail.com
# 1                      Terrier Mix             lindaelee@hotmail.com
# 2                 Pit Bull Terrier  info@thecatsmeowanimalrescue.org
# 3                 Pit Bull Terrier           idonotownacat@gmail.com
# 4   American Staffordshire Terrier           idonotownacat@gmail.com
# ..                             ...                               ...
# 90      Staffordshire Bull Terrier            DawnVargas05@yahoo.com
# 91                     Mixed Breed            DawnVargas05@yahoo.com
# 92             German Shepherd Dog            DawnVargas05@yahoo.com
# 93                  Siberian Husky      Herehaveakitteninc@gmail.com
# 94                Pit Bull Terrier      Herehaveakitteninc@gmail.com
#
# 0        Telephone                                          Image URL  \
# 0     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/09...
# 1     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/db...
# 2     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/47...
# 3     206-524-3066  https://dbw3zep4prcju.cloudfront.net/animal/60...
# 4     916-296-5195  https://dbw3zep4prcju.cloudfront.net/animal/d7...
# ..             ...                                                ...
# 90  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/cd...
# 91  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a5...
# 92  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a9...
# 93  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/5b...
# 94  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/76...
#
# 0   Access URL                                  Location  \
# 0   Click Here               nan, Los Angeles, CA, 90210
# 1   Click Here               nan, Los Angeles, CA, 90210
# 2   Click Here               nan, Los Angeles, CA, 90210
# 3   Click Here   999 Main street, Los Angeles, CA, 90067
# 4   Click Here   999 Main street, Los Angeles, CA, 90067
# ..         ...                                       ...
# 90  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 91  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 92  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 93  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 94  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
#
# 0                                 Coordinate        lat         lng
# 0                   (34.052235, -118.243683)  34.052235 -118.243683
# 1                   (34.052235, -118.243683)  34.052235 -118.243683
# 2                   (34.052235, -118.243683)  34.052235 -118.243683
# 3                   (33.991801, -118.473835)  33.991801 -118.473835
# 4                   (33.991801, -118.473835)  33.991801 -118.473835
# ..                                       ...        ...         ...
# 90  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 91  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 92  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 93  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 94  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
#
# [95 rows x 15 columns]

# %%
dog_data
# Out:
# 0        NAME    Street Address         City State Postal Code    Age  \
# 0       Lizzy               NaN  Los Angeles    CA       90210  Puppy
# 1      Autumn               NaN  Los Angeles    CA       90210  Puppy
# 2      Cookie               NaN  Los Angeles    CA       90210  Young
# 3      Buster   999 Main street  Los Angeles    CA       90067  Adult
# 4        Abby   999 Main street  Los Angeles    CA       90067  Adult
# ..        ...               ...          ...   ...         ...    ...
# 90     Watson  3201 Lacy Street  Los Angeles    CA       90031  Adult
# 91       Zara  3201 Lacy Street  Los Angeles    CA       90031  Adult
# 92      Ellie  3201 Lacy Street  Los Angeles    CA       90031  Young
# 93  Valentina  3201 Lacy Street  Los Angeles    CA       90031  Young
# 94   Cafesita  3201 Lacy Street  Los Angeles    CA       90031  Adult
#
# 0                            Breed                             Email  \
# 0                      Terrier Mix             lindaelee@hotmail.com
# 1                      Terrier Mix             lindaelee@hotmail.com
# 2                 Pit Bull Terrier  info@thecatsmeowanimalrescue.org
# 3                 Pit Bull Terrier           idonotownacat@gmail.com
# 4   American Staffordshire Terrier           idonotownacat@gmail.com
# ..                             ...                               ...
# 90      Staffordshire Bull Terrier            DawnVargas05@yahoo.com
# 91                     Mixed Breed            DawnVargas05@yahoo.com
# 92             German Shepherd Dog            DawnVargas05@yahoo.com
# 93                  Siberian Husky      Herehaveakitteninc@gmail.com
# 94                Pit Bull Terrier      Herehaveakitteninc@gmail.com
#
# 0        Telephone                                          Image URL  \
# 0     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/09...
# 1     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/db...
# 2     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/47...
# 3     206-524-3066  https://dbw3zep4prcju.cloudfront.net/animal/60...
# 4     916-296-5195  https://dbw3zep4prcju.cloudfront.net/animal/d7...
# ..             ...                                                ...
# 90  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/cd...
# 91  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a5...
# 92  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a9...
# 93  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/5b...
# 94  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/76...
#
# 0   Access URL                                  Location  \
# 0   Click Here               nan, Los Angeles, CA, 90210
# 1   Click Here               nan, Los Angeles, CA, 90210
# 2   Click Here               nan, Los Angeles, CA, 90210
# 3   Click Here   999 Main street, Los Angeles, CA, 90067
# 4   Click Here   999 Main street, Los Angeles, CA, 90067
# ..         ...                                       ...
# 90  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 91  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 92  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 93  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 94  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
#
# 0                                 Coordinate
# 0                   (34.052235, -118.243683)
# 1                   (34.052235, -118.243683)
# 2                   (34.052235, -118.243683)
# 3                   (33.991801, -118.473835)
# 4                   (33.991801, -118.473835)
# ..                                       ...
# 90  (34.08370692586621, -118.21807957472903)
# 91  (34.08370692586621, -118.21807957472903)
# 92  (34.08370692586621, -118.21807957472903)
# 93  (34.08370692586621, -118.21807957472903)
# 94  (34.08370692586621, -118.21807957472903)
#
# [95 rows x 13 columns]

# %%
dog_coord.to_csv('Dog_CA.csv', index=False)

# %%
dog_data
# Out:
# 0        NAME         City State Postal Code    Age  \
# 3      Buster  Los Angeles    CA       90067  Adult
# 4        Abby  Los Angeles    CA       90067  Adult
# 5       Lenni  Los Angeles    CA       90031  Young
# 6       Hanna  Los Angeles    CA       90031  Young
# 7       Tucan  Los Angeles    CA       90031  Young
# ..        ...          ...   ...         ...    ...
# 90     Watson  Los Angeles    CA       90031  Adult
# 91       Zara  Los Angeles    CA       90031  Adult
# 92      Ellie  Los Angeles    CA       90031  Young
# 93  Valentina  Los Angeles    CA       90031  Young
# 94   Cafesita  Los Angeles    CA       90031  Adult
#
# 0                            Breed  \
# 3                 Pit Bull Terrier
# 4   American Staffordshire Terrier
# 5          German Shepherd Dog Mix
# 6          German Shepherd Dog Mix
# 7             Pit Bull Terrier Mix
# ..                             ...
# 90      Staffordshire Bull Terrier
# 91                     Mixed Breed
# 92             German Shepherd Dog
# 93                  Siberian Husky
# 94                Pit Bull Terrier
#
# 0                                           Image URL  Access URL  \
# 3   https://dbw3zep4prcju.cloudfront.net/animal/60...  Click Here
# 4   https://dbw3zep4prcju.cloudfront.net/animal/d7...  Click Here
# 5   https://dbw3zep4prcju.cloudfront.net/animal/c9...  Click Here
# 6   https://dbw3zep4prcju.cloudfront.net/animal/b6...  Click Here
# 7   https://dbw3zep4prcju.cloudfront.net/animal/a5...  Click Here
# ..                                                ...         ...
# 90  https://dbw3zep4prcju.cloudfront.net/animal/cd...  Click Here
# 91  https://dbw3zep4prcju.cloudfront.net/animal/a5...  Click Here
# 92  https://dbw3zep4prcju.cloudfront.net/animal/a9...  Click Here
# 93  https://dbw3zep4prcju.cloudfront.net/animal/5b...  Click Here
# 94  https://dbw3zep4prcju.cloudfront.net/animal/76...  Click Here
#
# 0                                   Location  \
# 3    999 Main street, Los Angeles, CA, 90067
# 4    999 Main street, Los Angeles, CA, 90067
# 5   3201 Lacy Street, Los Angeles, CA, 90031
# 6   3201 Lacy Street, Los Angeles, CA, 90031
# 7   3201 Lacy Street, Los Angeles, CA, 90031
# ..                                       ...
# 90  3201 Lacy Street, Los Angeles, CA, 90031
# 91  3201 Lacy Street, Los Angeles, CA, 90031
# 92  3201 Lacy Street, Los Angeles, CA, 90031
# 93  3201 Lacy Street, Los Angeles, CA, 90031
# 94  3201 Lacy Street, Los Angeles, CA, 90031
#
# 0                                 Coordinate        lat         lng
# 3                   (33.991801, -118.473835)  33.991801 -118.473835
# 4                   (33.991801, -118.473835)  33.991801 -118.473835
# 5   (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 6   (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 7   (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# ..                                       ...        ...         ...
# 90  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 91  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 92  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 93  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 94  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
#
# [92 rows x 12 columns]

# %%
dog_coord["Shelter"] = dog_coord["Location"].apply(
    lambda loc: "City of Los Angeles North Central Animal Shelter"
    if loc == "3201 Lacy Street, Los Angeles, CA, 90031"
    else ("Los Angeles Rescue" if loc == "999 Main street, Los Angeles, CA, 90067"
          else "Pet Rescue Association LA")
)

# %%
dog_coord
# Out:
# 0        NAME    Street Address         City State Postal Code    Age  \
# 0       Lizzy               NaN  Los Angeles    CA       90210  Puppy
# 1      Autumn               NaN  Los Angeles    CA       90210  Puppy
# 2      Cookie               NaN  Los Angeles    CA       90210  Young
# 3      Buster   999 Main street  Los Angeles    CA       90067  Adult
# 4        Abby   999 Main street  Los Angeles    CA       90067  Adult
# ..        ...               ...          ...   ...         ...    ...
# 90     Watson  3201 Lacy Street  Los Angeles    CA       90031  Adult
# 91       Zara  3201 Lacy Street  Los Angeles    CA       90031  Adult
# 92      Ellie  3201 Lacy Street  Los Angeles    CA       90031  Young
# 93  Valentina  3201 Lacy Street  Los Angeles    CA       90031  Young
# 94   Cafesita  3201 Lacy Street  Los Angeles    CA       90031  Adult
#
# 0                            Breed                             Email  \
# 0                      Terrier Mix             lindaelee@hotmail.com
# 1                      Terrier Mix             lindaelee@hotmail.com
# 2                 Pit Bull Terrier  info@thecatsmeowanimalrescue.org
# 3                 Pit Bull Terrier           idonotownacat@gmail.com
# 4   American Staffordshire Terrier           idonotownacat@gmail.com
# ..                             ...                               ...
# 90      Staffordshire Bull Terrier            DawnVargas05@yahoo.com
# 91                     Mixed Breed            DawnVargas05@yahoo.com
# 92             German Shepherd Dog            DawnVargas05@yahoo.com
# 93                  Siberian Husky      Herehaveakitteninc@gmail.com
# 94                Pit Bull Terrier      Herehaveakitteninc@gmail.com
#
# 0        Telephone                                          Image URL  \
# 0     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/09...
# 1     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/db...
# 2     310-726-3731  https://dbw3zep4prcju.cloudfront.net/animal/47...
# 3     206-524-3066  https://dbw3zep4prcju.cloudfront.net/animal/60...
# 4     916-296-5195  https://dbw3zep4prcju.cloudfront.net/animal/d7...
# ..             ...                                                ...
# 90  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/cd...
# 91  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a5...
# 92  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/a9...
# 93  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/5b...
# 94  (409) 504-2519  https://dbw3zep4prcju.cloudfront.net/animal/76...
#
# 0   Access URL                                  Location  \
# 0   Click Here               nan, Los Angeles, CA, 90210
# 1   Click Here               nan, Los Angeles, CA, 90210
# 2   Click Here               nan, Los Angeles, CA, 90210
# 3   Click Here   999 Main street, Los Angeles, CA, 90067
# 4   Click Here   999 Main street, Los Angeles, CA, 90067
# ..         ...                                       ...
# 90  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 91  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 92  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 93  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
# 94  Click Here  3201 Lacy Street, Los Angeles, CA, 90031
#
# 0                                 Coordinate        lat         lng  \
# 0                   (34.052235, -118.243683)  34.052235 -118.243683
# 1                   (34.052235, -118.243683)  34.052235 -118.243683
# 2                   (34.052235, -118.243683)  34.052235 -118.243683
# 3                   (33.991801, -118.473835)  33.991801 -118.473835
# 4                   (33.991801, -118.473835)  33.991801 -118.473835
# ..                                       ...        ...         ...
# 90  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 91  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 92  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 93  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 94  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
#
# 0                                            Shelter
# 0                          Pet Rescue Association LA
# 1                          Pet Rescue Association LA
# 2                          Pet Rescue Association LA
# 3                                 Los Angeles Rescue
# 4                                 Los Angeles Rescue
# ..                                               ...
# 90  City of Los Angeles North Central Animal Shelter
# 91  City of Los Angeles North Central Animal Shelter
# 92  City of Los Angeles North Central Animal Shelter
# 93  City of Los Angeles North Central Animal Shelter
# 94  City of Los Angeles North Central Animal Shelter
#
# [95 rows x 16 columns]

# %%
dog_coord.to_csv('Dog_CA.csv', index=False)

# %%
dogs_df = pd.read_csv('https://raw.githubusercontent.com/TheLazyCactus/Data_Thieves_project/refs/heads/main/Dog_CA.csv', encoding='latin1')
dogs_df
# Out:
#          NAME         City State  Postal Code    Age  \
# 0      Buster  Los Angeles    CA        90067  Adult
# 1        Abby  Los Angeles    CA        90067  Adult
# 2       Lenni  Los Angeles    CA        90031  Young
# 3       Hanna  Los Angeles    CA        90031  Young
# 4       Tucan  Los Angeles    CA        90031  Young
# ..        ...          ...   ...          ...    ...
# 87     Watson  Los Angeles    CA        90031  Adult
# 88       Zara  Los Angeles    CA        90031  Adult
# 89      Ellie  Los Angeles    CA        90031  Young
# 90  Valentina  Los Angeles    CA        90031  Young
# 91   Cafesita  Los Angeles    CA        90031  Adult
#
#                              Breed  \
# 0                 Pit Bull Terrier
# 1   American Staffordshire Terrier
# 2          German Shepherd Dog Mix
# 3          German Shepherd Dog Mix
# 4             Pit Bull Terrier Mix
# ..                             ...
# 87      Staffordshire Bull Terrier
# 88                     Mixed Breed
# 89             German Shepherd Dog
# 90                  Siberian Husky
# 91                Pit Bull Terrier
#
#                                             Image URL  Access URL  \
# 0   https://dbw3zep4prcju.cloudfront.net/animal/60...  Click Here
# 1   https://dbw3zep4prcju.cloudfront.net/animal/d7...  Click Here
# 2   https://dbw3zep4prcju.cloudfront.net/animal/c9...  Click Here
# 3   https://dbw3zep4prcju.cloudfront.net/animal/b6...  Click Here
# 4   https://dbw3zep4prcju.cloudfront.net/animal/a5...  Click Here
# ..                                                ...         ...
# 87  https://dbw3zep4prcju.cloudfront.net/animal/cd...  Click Here
# 88  https://dbw3zep4prcju.cloudfront.net/animal/a5...  Click Here
# 89  https://dbw3zep4prcju.cloudfront.net/animal/a9...  Click Here
# 90  https://dbw3zep4prcju.cloudfront.net/animal/5b...  Click Here
# 91  https://dbw3zep4prcju.cloudfront.net/animal/76...  Click Here
#
#                                     Location  \
# 0    999 Main street, Los Angeles, CA, 90067
# 1    999 Main street, Los Angeles, CA, 90067
# 2   3201 Lacy Street, Los Angeles, CA, 90031
# 3   3201 Lacy Street, Los Angeles, CA, 90031
# 4   3201 Lacy Street, Los Angeles, CA, 90031
# ..                                       ...
# 87  3201 Lacy Street, Los Angeles, CA, 90031
# 88  3201 Lacy Street, Los Angeles, CA, 90031
# 89  3201 Lacy Street, Los Angeles, CA, 90031
# 90  3201 Lacy Street, Los Angeles, CA, 90031
# 91  3201 Lacy Street, Los Angeles, CA, 90031
#
#                                   Coordinate        lat         lng  \
# 0                   (33.991801, -118.473835)  33.991801 -118.473835
# 1                   (33.991801, -118.473835)  33.991801 -118.473835
# 2   (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 3   (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 4   (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# ..                                       ...        ...         ...
# 87  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 88  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 89  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 90  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
# 91  (34.08370692586621, -118.21807957472903)  34.083707 -118.218080
#
#                                              Shelter
# 0                                 Los Angeles Rescue
# 1                                 Los Angeles Rescue
# 2   City of Los Angeles North Central Animal Shelter
# 3   City of Los Angeles North Central Animal Shelter
# 4   City of Los Angeles North Central Animal Shelter
# ..                                               ...
# 87  City of Los Angeles North Central Animal Shelter
# 88  City of Los Angeles North Central Animal Shelter
# 89  City of Los Angeles North Central Animal Shelter
# 90  City of Los Angeles North Central Animal Shelter
# 91  City of Los Angeles North Central Animal Shelter
#
# [92 rows x 13 columns]
